# %% [markdown]
# # KBBQ Hit Location Project

# %% [markdown]
# ## *Introduction*
# #### While travelling in New York, we noticed that there aren't as many Korean BBQ restaurants as other ethnic restaurants such as Itallian or Japanese in Manhattan, New York.
# #### Some of the Korean BBQ restaurants that we visited such as Jongro BBQ on 32nd Street seemed to be very busy and making a lot of profit with fully booked tables and people waiting in line for over an hour to be served.
# #### However, we barely saw Korean BBQ restaurants, if not none, in other parts of Manhattan.  We want to find the best possible location for a Korean BBQ restaurant in a location where population traffic is dense but little or no Korean restaurants are around.
# #### In addition, we want to avoid other types of BBQ restaurants as they could become serious competitors.

# %% [markdown]
# ## *Data Description*
# #### First, we need to find locations of all Korean BBQ restaurants and locations of restaurants that serve similar food.  This can be done using the Foursquare API and using keywords such as BBQ, Restaurants, and etc.  We will be showing the dataset in the Methodology section.
# #### Second, we need to determine population traffic at these locations.  We can determine this by looking at rating counts and tip counts.  We will be manipulating location data as well as venue data to merge to get the final dataset.

# %% [markdown]
# ## *Methodology*
# #### We will merge location and venue data and preprocess the merged dataset.  Once preprocessing is done, we will apply 75th percentile condition on rating, rating counts, and tip counts columns to determine which areas can be hot spots.

# %%
# Import libraries

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json
from geopy.geocoders import Nominatim
import requests
from pandas import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %%
CLIENT_ID = 'ID'
CLIENT_SECRET = 'SECRET'
ACCESS_TOKEN = 'TOKEN'
VERSION = '20180604'
LIMIT = 1000

# %% [markdown]
# ### We want to first find where KBBQ and other BBQ restaurants are located in Manhanttan.

# %%
address = '22 W 32nd St, New York, NY'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

search_query = 'BBQ'
radius = 10000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()
venues = results['response']['venues']
dataframe = json_normalize(venues)

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered.sort_values(by='distance',ascending=True, inplace=True)
dataframe_filtered = dataframe_filtered[dataframe_filtered['categories'].str.contains('Restaurant',na=False,regex=False)]
dataframe_filtered
# Out:
#                                name           categories  \
# 0                        Jongro BBQ    Korean Restaurant
# 22                       The Kunjip    Korean Restaurant
# 4                  Chung Moo Ro BBQ    Korean Restaurant
# 10                   miss KOREA BBQ    Korean Restaurant
# 1                 Samwon Garden BBQ    Korean Restaurant
# 6                 K-Town BBQ (고기주점)    Korean Restaurant
# 14                  LOVE Korean BBQ    Korean Restaurant
# 2     Don's Bogam Korean BBQ & Wine    Korean Restaurant
# 26              Hongchun Korean BBQ    Korean Restaurant
# 35   Oppa New Korean BBQ @madsqeats    Korean Restaurant
# 32            Fire Belly Korean BBQ    Korean Restaurant
# 43                   Bap Korean BBQ    Korean Restaurant
# 44                   LiveIntent BBQ  American Restaurant
# 23                            BBQ's  American Restaurant
# 12                      ZLS BBQ INC   Chinese Restaurant
# 9             Gyu-Kaku Japanese BBQ  Japanese Restaurant
# 49          Braddah's: Hawaiian BBQ  Hawaiian Restaurant
# 18  Ding BBQ and Hot Pot Restaurant    Hotpot Restaurant
# 11            Gyu-Kaku Japanese BBQ  Japanese Restaurant
#
#                             address                      crossStreet  \
# 0                 22 W 32nd St Fl 2          btwn Broadway & 5th Ave
# 22                     32 W 32nd St          btwn Broadway & 5th Ave
# 4                      10 W 32nd St                         5th Ave.
# 10             10 W 32nd St Fl 3 #1          btwn Broadway & 5th Ave
# 1                      37 W 32nd St               btwn 5th & 6th Ave
# 6                2 W 32nd St Frnt 2                              NaN
# 14                      319 5th Ave                              NaN
# 2                     17 E 32nd St.            Between Madison & 5th
# 26       739 Avenue of the Americas                     6th And 27th
# 35                              NaN                              NaN
# 32                    Mad. Sq. Eats  Worth Sq at w 25th St & 5th Ave
# 43                      516 3rd Ave            34th And 35th Streets
# 44                              NaN                              NaN
# 23                    247 W 24th St                         8th Ave.
# 12                    219 E 23rd St                              NaN
# 9                     321 W 44th St               btwn 8th & 9th Ave
# 49  74 5th Avenue, Greenwich Social                              NaN
# 18                    234 W 48th St          btwn Broadway & 8th Ave
# 11                      805 3rd Ave          btwn E 49th & E 50th St
#
#           lat        lng                                     labeledLatLngs  \
# 0   40.747574 -73.987043  [{'label': 'display', 'lat': 40.747574, 'lng':...
# 22  40.747945 -73.987134  [{'label': 'display', 'lat': 40.74794485506209...
# 4   40.747311 -73.986464  [{'label': 'display', 'lat': 40.74731099999999...
# 10  40.747286 -73.986410  [{'label': 'display', 'lat': 40.747286, 'lng':...
# 1   40.748010 -73.987280  [{'label': 'display', 'lat': 40.74801, 'lng': ...
# 6   40.747418 -73.986121  [{'label': 'display', 'lat': 40.74741821848371...
# 14  40.747163 -73.985188  [{'label': 'display', 'lat': 40.747163, 'lng':...
# 2   40.746788 -73.984444  [{'label': 'display', 'lat': 40.74678829586255...
# 26  40.745432 -73.990989  [{'label': 'display', 'lat': 40.74543229305341...
# 35  40.742676 -73.988920  [{'label': 'display', 'lat': 40.742676, 'lng':...
# 32  40.742617 -73.989066  [{'label': 'display', 'lat': 40.74261695988245...
# 43  40.746136 -73.977892  [{'label': 'display', 'lat': 40.746136, 'lng':...
# 44  40.739922 -73.987528  [{'label': 'display', 'lat': 40.73992158382056...
# 23  40.745682 -73.996925  [{'label': 'display', 'lat': 40.74568176269531...
# 12  40.738636 -73.981918  [{'label': 'display', 'lat': 40.7386360168457,...
# 9   40.759042 -73.990043  [{'label': 'display', 'lat': 40.75904160050783...
# 49  40.735775 -73.994282  [{'label': 'display', 'lat': 40.73577493911153...
# 18  40.760728 -73.986184  [{'label': 'display', 'lat': 40.76072758809209...
# 11  40.755731 -73.970897  [{'label': 'display', 'lat': 40.75573050425004...
#
#     distance postalCode  cc neighborhood      city state        country  \
# 0         10      10001  US    Koreatown  New York    NY  United States
# 22        46      10001  US          NaN  New York    NY  United States
# 4         47      10001  US          NaN  New York    NY  United States
# 10        52      10001  US          NaN  New York    NY  United States
# 1         58      10001  US    Koreatown  New York    NY  United States
# 6         68      10001  US          NaN  New York    NY  United States
# 14       152      10016  US          NaN  New York    NY  United States
# 2        225      10016  US          NaN  New York    NY  United States
# 26       417      10010  US          NaN  New York    NY  United States
# 35       569        NaN  US          NaN  New York    NY  United States
# 32       579        NaN  US          NaN  New York    NY  United States
# 43       777      10016  US          NaN  New York    NY  United States
# 44       852        NaN  US          NaN  New York    NY  United States
# 23       869      10011  US          NaN  New York    NY  United States
# 12      1079      10010  US          NaN  New York    NY  United States
# 9       1304      10036  US          NaN  New York    NY  United States
# 49      1451      10011  US          NaN  New York    NY  United States
# 18      1466      10036  US          NaN  New York    NY  United States
# 11      1628      10022  US          NaN  New York    NY  United States
#
#                                      formattedAddress  \
# 0   [22 W 32nd St Fl 2 (btwn Broadway & 5th Ave), ...
# 22  [32 W 32nd St (btwn Broadway & 5th Ave), New Y...
# 4       [10 W 32nd St (5th Ave.), New York, NY 10001]
# 10  [10 W 32nd St Fl 3 #1 (btwn Broadway & 5th Ave...
# 1   [37 W 32nd St (btwn 5th & 6th Ave), New York, ...
# 6            [2 W 32nd St Frnt 2, New York, NY 10001]
# 14                  [319 5th Ave, New York, NY 10016]
# 2   [17 E 32nd St. (Between Madison & 5th), New Yo...
# 26  [739 Avenue of the Americas (6th And 27th), Ne...
# 35                                     [New York, NY]
# 32  [Mad. Sq. Eats (Worth Sq at w 25th St & 5th Av...
# 43  [516 3rd Ave (34th And 35th Streets), New York...
# 44                                     [New York, NY]
# 23     [247 W 24th St (8th Ave.), New York, NY 10011]
# 12                [219 E 23rd St, New York, NY 10010]
# 9   [321 W 44th St (btwn 8th & 9th Ave), New York,...
# 49  [74 5th Avenue, Greenwich Social, New York, NY...
# 18  [234 W 48th St (btwn Broadway & 8th Ave), New ...
# 11  [805 3rd Ave (btwn E 49th & E 50th St), New Yo...
#
#                           id
# 0   540f86da498e020149fa7676
# 22  49e6e227f964a52074641fe3
# 4   4a1e0dd2f964a520c07b1fe3
# 10  4c254ba6136d20a19f63e361
# 1   5aab0d2ae179107b87768ff8
# 6   5a2c7151a22db744e299c521
# 14  5e3b69b257fcde0008c0c3a3
# 2   41e46880f964a520d81e1fe3
# 26  532891cd498e46e4f3868cca
# 35  591dece61543c72695710ae0
# 32  555160fb498e260e46599e32
# 43  5ba44739a4ba7c002c067b0d
# 44  51dde000498e966ff7135185
# 23  4d7ffb24e6d7721ef71210c7
# 12  5e5bebea36734600083cd6f0
# 9   4ef0d81fbe7ba3ed7c2296d2
# 49  5fb32364884a0f4a6145ed4d
# 18  57041d93498eefdff07820df
# 11  48208c8cf964a520894f1fe3

# %% [markdown]
# ### The map below shows all BBQ restaurants seem to be located in the midtown of Manhattan.

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Jongro BBQ
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Jongro BBQ',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the BBQ restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b546fe7acc13450fba569f9a5a23450f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b546fe7acc13450fba569f9a5a23450f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b546fe7acc13450fba569f9a5a23450f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b546fe7acc13450fba569f9a5a23450f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7475612%2C%20-73.9869147%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Restaurants in Lower Manhattan

# %%
address = '138 Lafayette St, New York, NY 10013'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

search_query = 'Restaurant'
radius = 2000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()
venues = results['response']['venues']
dataframe = json_normalize(venues)

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered.sort_values(by='distance',ascending=True, inplace=True)
dataframe_filtered = dataframe_filtered[dataframe_filtered['categories'].str.contains('Restaurant',na=False,regex=False)]
total_data = dataframe_filtered.copy()

# %% [markdown]
# ### Restaurants in Upper Manhattan

# %%
address = '1544 Madison Ave, New York, NY 10029'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

search_query = 'Restaurant'
radius = 2000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()
venues = results['response']['venues']
dataframe = json_normalize(venues)

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered.sort_values(by='distance',ascending=True, inplace=True)
dataframe_filtered = dataframe_filtered[dataframe_filtered['categories'].str.contains('Restaurant',na=False,regex=False)]
total_data = total_data.append(dataframe_filtered)

# %% [markdown]
# ### We merge lower and upper manhattan datasets.

# %%
total_data = pd.DataFrame(total_data, index=None)
total_data
# Out:
#                                              name  \
# 9                 Canal Street Seafood Restaurant
# 13                  Canal Best Chinese Restaurant
# 12                         Sun Sai Gai Restaurant
# 21                   Beijing Pop Kabob Restaurant
# 8                               Puglia Restaurant
# 20                              Lunela Restaurant
# 3                                Galli Restaurant
# 2                        Royal Seafood Restaurant
# 7                      Shanghai Heping Restaurant
# 10                       Hoy Wong Restaurant 喜喜饭店
# 37                  Grand Bo Ky Restaurant 波記潮州小食
# 5                                  218 Restaurant
# 27                   East Boat Seafood Restaurant
# 28                 Dragon Gate Chinese Restaurant
# 1                         Bo Ky Restaurant 波記潮州小食
# 11               New Hong Wong Seafood Restaurant
# 25        Wing Kee WK Restaurant 榮記飯店 (former 69)
# 0                      Deluxe Green Bo Restaurant
# 30           Hunger Pop-Up Restaurant at The Yard
# 34                        White Street Restaurant
# 4                   Nam Son Vietnamese Restaurant
# 38                     Chatham Seafood Restaurant
# 44         Great Fortune Chinese Restaurant 聚旺茶餐廳
# 6                  Golden Unicorn Restaurant 麒麟金閣
# 48                          New Shezan Restaurant
# 46                          Food World Restaurant
# 31                            Fei Tenc Restaurant
# 42                       Mei Yu Spring Restaurant
# 36                            New Wong Restaurant
# 14                            Arturo's Restaurant
# 43                   El Nuevo Amanecer Restaurant
# 41                   TJ Byrnes Bar and Restaurant
# 16                               Frank Restaurant
# 39                                 Ise Restaurant
# 47              Panna II Garden Indian Restaurant
# 2                           Giovanna's Restaurant
# 0                               Judy's Restaurant
# 8                     Spice Hut Indian Restaurant
# 4                     Lolita's Mexican Restaurant
# 48                       Restaurant San Cristobal
# 7                       Indo Pak Halal Restaurant
# 17                       No. 1 Chinese Restaurant
# 18                   Wing Sing Chinese Restaurant
# 46                         The Restaurant at MIST
# 19                    Fa Shing Chinese Restaurant
# 3                            Chinatown Restaurant
# 26                             Sandy's Restaurant
# 9                       Pipo's Mexican Restaurant
# 24                                 Lex Restaurant
# 13                       Polash Indian restaurant
# 29                      Adam's Chinese Restaurant
# 31       Freddy's Soul Caribbean Restaurant, Inc.
# 34                              Mama’s Restaurant
# 33                      Halal Indo Pak Restaurant
# 32                    Wing Wah Chinese Restaurant
# 35                       Acosta Deli - Restaurant
# 21                      Chocolat Restaurant & Bar
# 14                         El Ranchito Restaurant
# 12                          Malecon Restaurant II
# 41                             Manna's Restaurant
# 36                               Accra Restaurant
# 6                           Heidelberg Restaurant
# 30             Manna's Soul Food Restaurant - FDB
# 11                     Kouzan Japanese Restaurant
# 25                                Poke Restaurant
# 22                             Gennaro Restaurant
# 28                            Sylvia's Restaurant
# 43                              One 83 Restaurant
# 20                   Carmine's Italian Restaurant
# 18                                     NaN  40.798323 -73.941637
# 46                                     NaN  40.801516 -73.948327
# 19                                     NaN  40.797315 -73.940161
# 3                  btwn E 92nd & E 93rd St  40.782745 -73.950935
# 26                                     NaN  40.797019 -73.937958
# 9                btwn Lexington & 3rd Ave.  40.799377 -73.939908
# 24                 btwn E 90th & E 91st St  40.782530 -73.953700
# 13                            at 119th St.  40.799745 -73.938747
# 29                                     NaN  40.781095 -73.949526
# 31                               119th St.  40.805181 -73.951164
# 34                                120th St  40.799830 -73.935859
# 33                                     NaN  40.779792 -73.946915
# 32                           at E 118th St  40.797486 -73.933994
# 35                                   106th  40.800293 -73.965621
# 21                           at W 120th St  40.806982 -73.953751
# 14                                     NaN  40.800609 -73.966782
# 12                   btw 97th St & 98th St  40.794932 -73.969648
# 41                          at Madison Ave  40.805731 -73.940458
# 36                    At West 122nd street  40.807868 -73.949107
# 6                     btwn 85th & 86th St.  40.777532 -73.951979
# 30                           Lenox and 5th  40.807581 -73.944898
# 11                            West 93rd St  40.792213 -73.971664
# 25                      btwn 1st & 2nd Ave  40.776508 -73.950548
# 22                               W 93rd St  40.791932 -73.971931
# 28               btwn W 126th & W 127th St  40.808705 -73.944725
# 43                            at E 83rd St  40.775101 -73.950150
# 20                    btwn W 90th & W 91st  40.791096 -73.973991
# 42                Between 81th and 82nd St  40.774919 -73.954132
# 37                                     NaN  40.774816 -73.954492
# 40                              W 129th St  40.810219 -73.943755
# 16                 btwn E 80th & E 81st St  40.774581 -73.954206
# 45                       btw 129th & 130th  40.810685 -73.943337
# 38                     btwn 83rd & 84th St  40.784656 -73.973522
# 15                            at W 83rd St  40.785658 -73.976539
# 27                          at Madison Ave  40.774814 -73.965235
#
#                                        labeledLatLngs  distance postalCode  \
# 9   [{'label': 'display', 'lat': 40.718768, 'lng':...        74      10013
# 13  [{'label': 'display', 'lat': 40.71878993882605...        75      10013
# 12  [{'label': 'display', 'lat': 40.71736941942955...       207      10013
# 21  [{'label': 'display', 'lat': 40.71791177404022...       226      10013
# 8   [{'label': 'display', 'lat': 40.71816511464507...       231      10013
# 20  [{'label': 'display', 'lat': 40.720106, 'lng':...       280      10013
# 3   [{'label': 'display', 'lat': 40.72160721760932...       289      10013
# 2   [{'label': 'display', 'lat': 40.71730464970235...       308      10013
# 7   [{'label': 'display', 'lat': 40.71743807449281...       309      10013
# 10  [{'label': 'display', 'lat': 40.71660726686447...       342      10013
# 37  [{'label': 'display', 'lat': 40.71889236768727...       358      10013
# 5   [{'label': 'display', 'lat': 40.71883283355385...       370      10013
# 27  [{'label': 'display', 'lat': 40.72095489501953...       392      10012
# 28  [{'label': 'display', 'lat': 40.718358, 'lng':...       400      10013
# 1   [{'label': 'display', 'lat': 40.71569636637641...       403      10013
# 11  [{'label': 'display', 'lat': 40.717794, 'lng':...       429      10013
# 25  [{'label': 'display', 'lat': 40.71556547601636...       430      10013
# 0   [{'label': 'display', 'lat': 40.71554491813315...       436      10013
# 30  [{'label': 'display', 'lat': 40.72203826904297...       469      10013
# 34  [{'label': 'display', 'lat': 40.71924484269095...       496      10013
# 4   [{'label': 'display', 'lat': 40.71821452604745...       509      10002
# 38  [{'label': 'display', 'lat': 40.71388466954485...       606      10038
# 44  [{'label': 'display', 'lat': 40.713875, 'lng':...       635      10038
# 6   [{'label': 'display', 'lat': 40.71362850464683...       662      10002
# 48  [{'label': 'display', 'lat': 40.71578949233164...       694      10007
# 46  [{'label': 'display', 'lat': 40.71503642778741...       719      10002
# 31  [{'label': 'display', 'lat': 40.713854, 'lng':...       741      10002
# 42  [{'label': 'display', 'lat': 40.71246460866779...       786      10038
# 36  [{'label': 'display', 'lat': 40.71388902330584...       830      10002
# 14  [{'label': 'display', 'lat': 40.727407, 'lng':...       922      10012
# 43  [{'label': 'display', 'lat': 40.72103478699385...      1132      10002
# 41  [{'label': 'display', 'lat': 40.70923312629616...      1138      10038
# 16  [{'label': 'display', 'lat': 40.7269388318875,...      1295      10003
# 39  [{'label': 'display', 'lat': 40.729124, 'lng':...      1412      10003
# 47  [{'label': 'display', 'lat': 40.72627299004598...      1424      10003
# 2   [{'label': 'display', 'lat': 40.78852325970528...       482      10029
# 0   [{'label': 'display', 'lat': 40.78668052588666...       673      10029
# 8   [{'label': 'display', 'lat': 40.789675, 'lng':...       727      10029
# 4   [{'label': 'display', 'lat': 40.80009296395034...       822      10026
# 48  [{'label': 'display', 'lat': 40.79112612055735...       918      10029
# 7   [{'label': 'display', 'lat': 40.79421852999601...       921      10029
# 17  [{'label': 'display', 'lat': 40.801317, 'lng':...       957      10026
# 18  [{'label': 'display', 'lat': 40.79832299999999...       966      10029
# 46  [{'label': 'display', 'lat': 40.80151563049761...       993      10026
# 19  [{'label': 'display', 'lat': 40.79731500000000...      1003      10029
# 3   [{'label': 'display', 'lat': 40.78274531667897...      1112      10128
# 26  [{'label': 'display', 'lat': 40.79701855664365...      1153      10035
# 9   [{'label': 'display', 'lat': 40.799377, 'lng':...      1153      10035
# 24  [{'label': 'display', 'lat': 40.78253, 'lng': ...      1169      10128
# 13  [{'label': 'display', 'lat': 40.79974477464853...      1255      10035
# 29  [{'label': 'display', 'lat': 40.78109509426577...      1297      10128
# 31  [{'label': 'display', 'lat': 40.80518114388907...      1386      10039
# 34  [{'label': 'display', 'lat': 40.79982963049066...      1459      10035
# 33  [{'label': 'display', 'lat': 40.779792, 'lng':...      1470      10128
# 32  [{'label': 'display', 'lat': 40.797486, 'lng':...      1481      10035
# 35  [{'label': 'display', 'lat': 40.80029263884989...      1532      10025
# 21  [{'label': 'display', 'lat': 40.8069823, 'lng'...      1610      10026
# 14  [{'label': 'display', 'lat': 40.8006088851318,...      1633      10025
# 12  [{'label': 'display', 'lat': 40.79493159833159...      1638      10025
# 41  [{'label': 'display', 'lat': 40.80573118943486...      1672      10035
# 36  [{'label': 'display', 'lat': 40.80786779413678...      1688      10027
# 6   [{'label': 'display', 'lat': 40.77753193843934...      1697      10028
# 30  [{'label': 'display', 'lat': 40.80758133963213...      1716      10027
# 11  [{'label': 'display', 'lat': 40.79221265537916...      1791      10025
# 40  US  New York    NY  United States
# 16  US  New York    NY  United States
# 45  US  New York    NY  United States
# 38  US  New York    NY  United States
# 15  US  New York    NY  United States
# 27  US  New York    NY  United States
#
#                                      formattedAddress    neighborhood  \
# 9                  [266 Canal St, New York, NY 10013]             NaN
# 13                 [266 Canal St, New York, NY 10013]             NaN
# 12  [220 Canal St (at Baxter St), New York, NY 10013]             NaN
# 21              [122 Mulberry St, New York, NY 10013]             NaN
# 8   [189 Hester St (btwn Mott & Mulberry), New Yor...             NaN
# 20              [173 Mulberry St, New York, NY 10013]             NaN
# 3   [45 Mercer St (Broome & Grand Streets), New Yo...             NaN
# 2   [103-105 Mott St (btwn Canal & Hester St), New...             NaN
# 7   [104 Mott St (btwn Hester & Canal St), New Yor...             NaN
# 10    [81 Mott St (at Canal St.), New York, NY 10013]             NaN
# 37  [216 Grand St (btwn Mott and Elizabeth St), Ne...             NaN
# 5   [218 Grand St (btwn Elizabeth & Mott St.), New...             NaN
# 27                [72 Kenmare St, New York, NY 10012]             NaN
# 28              [92 Elizabeth St, New York, NY 10013]             NaN
# 1     [80 Bayard St (at Mott St), New York, NY 10013]             NaN
# 11  [100 Bowery (Between Hester street and Grand s...             NaN
# 25  [69 Bayard St (Mott Street And Elizabeth Stree...             NaN
# 0   [66 Bayard St (btwn Elizabeth & Mott St), New ...             NaN
# 30  [310 W Broadway (btwn Grand and Canal), New Yo...             NaN
# 34  [221 W Broadway (at White St), New York, NY 10...             NaN
# 4   [245 Grand St (btwn Bowery & Chrystie St), New...             NaN
# 38  [6 Chatham Sq (btwn Mott & Doyers St), New Yor...             NaN
# 44  [5 Catherine St (btwn E Broadway & Chatham Sq)...             NaN
# 6   [18 E Broadway (at Catherine St), New York, NY...             NaN
# 48  [183 Church St (btwn Duane & Reade St.), New Y...             NaN
# 46  [19 Eldridge St #B (canal street), New York, N...             NaN
# 31                [68 E Broadway, New York, NY 10002]             NaN
# 42      [29 Catherine St (Henry), New York, NY 10038]             NaN
# 36     [103 E Broadway (at Pike), New York, NY 10002]             NaN
# 14  [106 W Houston St (at Thompson St.), New York,...             NaN
# 43  [117 Stanton St (at Essex St), New York, NY 10...             NaN
# 41       [77 Fulton St (Gold St), New York, NY 10038]             NaN
# 16     [88 2nd Ave (at E 5th St), New York, NY 10003]             NaN
# 39  [63 Cooper Sq (btwn E 7th & E 8th St), New Yor...         East vi
# 47  [93 1st Ave (btwn 5th & 6th St), New York, NY ...             NaN
# 2   [1567 Lexington Ave (E. 100th Street), New Yor...             NaN
# 0            [1505 Lexington Ave, New York, NY 10029]             NaN
# 8     [2036 2nd Ave (105 Street), New York, NY 10029]             NaN
# 4   [57 Malcolm X Blvd (at 113th St), New York, NY...             NaN
# 48               [339 E 108th St, New York, NY 10029]             NaN
# 7     [2173 2nd Ave (112th. St.), New York, NY 10029]             NaN
# 17                [83 W 115th St, New York, NY 10026]             NaN
# 18           [1863 Lexington Ave, New York, NY 10029]             NaN
# 46                [46 W 116th St, New York, NY 10026]             NaN
# 19                 [2107 3rd Ave, New York, NY 10029]             NaN
# 3   [1650 3rd Ave (btwn E 92nd & E 93rd St), New Y...             NaN
# 26                 [2261 2nd Ave, New York, NY 10035]             NaN
# 9   [166 E 118th St (btwn Lexington & 3rd Ave.), N...             NaN
# 24  [1370 Lexington Ave (btwn E 90th & E 91st St),...             NaN
# 13  [2179 3rd Ave (at 119th St.), New York, NY 10035]             NaN
# 29                [301 E 90th St, New York, NY 10128]             NaN
# 31  [2537 Adam Clayton Powell Jr Blvd (119th St.),...             NaN
# 34      [2347 2nd Ave (120th St), New York, NY 10035]             NaN
# 33                 [1750 1st Ave, New York, NY 10128]             NaN
# 32  [2308 1st Ave (at E 118th St), New York, NY 10...             NaN
# 35    [934 Amsterdam Ave (106th), New York, NY 10025]             NaN
# 21  [2223 Frederick Douglass Blvd (at W 120th St),...             NaN
# 14            [924 Amsterdam Ave, New York, NY 10025]             NaN
# 12  [764 Amsterdam Ave (btw 97th St & 98th St), Ne...             NaN
# 41  [54 E.125th Street (at Madison Ave), New York,...             NaN
# 36  [2065 Adam Clayton Powell Jr Blvd (At West 122...  Central Harlem
# 6   [1648 2nd Ave (btwn 85th & 86th St.), New York...             NaN
# 30  [2353 Frederick Douglass Blvd (Lenox and 5th),...             NaN
# 11  [685 Amsterdam Ave (West 93rd St), New York, N...             NaN
# 25  [343 E 85th St (btwn 1st & 2nd Ave), New York,...             NaN
# 22  [665 Amsterdam Ave (W 93rd St), New York, NY 1...             NaN
# 28  [328 Malcolm X Blvd (btwn W 126th & W 127th St...             NaN
# 43  [1608 1st Ave (at E 83rd St), New York, NY 10028]             NaN
# 20  [2450 Broadway (btwn W 90th & W 91st), New Yor...             NaN
# 42  [1565 2nd Ave (Between 81th and 82nd St), New ...             NaN
# 37                [240 E 81st St, New York, NY 10028]             NaN
# 40  [373 Malcolm X Blvd (W 129th St), New York, NY...  Central Harlem
# 16  [1557 2nd Ave (btwn E 80th & E 81st St), New Y...             NaN
# 45  [393 Malcolm X Blvd (btw 129th & 130th), New Y...             NaN
# 38  [483 Columbus Ave (btwn 83rd & 84th St), New Y...             NaN
# 15  [476 Amsterdam Ave. (at W 83rd St), New York, ...             NaN
# 27  [35 E 76th St (at Madison Ave), New York, NY 1...             NaN
#
#                           id
# 9   4ab80dbff964a520fc7b20e3
# 13  4d83993c81fdb1f7cf87eabf
# 12  4a81ac53f964a5203af71fe3
# 21  540df8c8498e1524a6acd4f8
# 8   3fd66200f964a520ade61ee3
# 20  4f32b1c219836c91c7f095f1
# 3   5018507fe4b03a729d0b40f9
# 2   4bdd7814b0f5c928c4684ce3
# 7   4f19bd72e4b0808f629111d1
# 10  4a7b6d4df964a520fbea1fe3
# 37  4ae5afa0f964a52076a121e3
# 5   4bfdcd3ae529c928a589bb8c
# 27  4b9c3bc7f964a5206d5736e3
# 28  4e4e4c7abd4101d0d7a72532
# 1   4a00df67f964a520ba701fe3
# 11  57e40ce3498e7aa078dec848
# 25  56fd4c5e498e389de05f8b85
# 0   3fd66200f964a520ceea1ee3
# 30  4c58b527f346c9285ef24aca
# 34  53fccf6c498e83054e5a6e0b
# 4   4a7e3d0cf964a52088f11fe3
# 38  49c68407f964a52052571fe3
# 44  58aa398b14fb41097a0cf923
# 6   3fd66200f964a520ece31ee3
# 48  4c4890da1879c9b6cce6e143
# 46  4f4c2c77e4b05ebee37d2c8a
# 31  4cd89f4451fc8cfa5dc1ea5d
# 42  511d6951e4b0b10a3986bb7a
# 36  4cba18bf035d236a3b46d84e
# 14  3fd66200f964a5209ae31ee3
# 43  440e9d36f964a5209f301fe3
# 41  4b4fdfc8f964a520801827e3
# 16  3fd66200f964a5204de41ee3
# 39  56f5d9d7498e00fbd06e7421
# 47  4116be80f964a520f90b1fe3
# 2   4a7b0914f964a520d7e91fe3
# 0   4e248a5fe4cdf68591a40adf
# 8   545eb9de498ed803ac5569c4
# 4   4ad51d0cf964a520f40121e3
# 48  51781bb2e4b03789cbc910b1
# 7   4cf94bfa7f2db1f7796520d4
# 17  4f14ba2ae4b03856f3a57a74
# 18  4e4e4f67bd4101d0d7a76773
# 46  56335bb7498e49f5008f563b
# 19  4c44f0662d3ec9b63fa32fae
# 3   4b292040f964a520459924e3
# 26  4b688392f964a520397d2be3
# 9   4e4e4f65bd4101d0d7a76740
# 24  4aad53a2f964a520b75f20e3
# 13  4a60aa67f964a520f9c01fe3
# 29  4f29e824e4b0e2cf5db548d7
# 31  4bb0d4e9f964a52018613ce3
# 34  4f88b73de4b0ab5c8748ba31
# 33  4e4c3addbd413c4cc667d299
# 32  4c19239a98f4a593dd9ffff5
# 35  4cb1f440c5e6a1cd2cbfe1f6
# 21  505e7359e4b081c354756ba1
# 14  4bfc6242da7120a163ff49fd
# 12  4a2eb2b0f964a52036981fe3
# 41  4be203d2660ec9282681c83b
# 36  513e60d0e4b0fa5192b9179b
# 6   439e1fd8f964a520092c1fe3
# 30  4aeb7d9ff964a5209cc221e3
# 11  49e61c9df964a52009641fe3
# 25  4a0d5a23f964a52077751fe3
# 22  4abc2282f964a5208a8620e3
# 28  3fd66200f964a52069e81ee3
# 43  4c009167ad15a59337328e73
# 20  4a7778a1f964a5209be41fe3
# 42  4e4c3209d22d10a6c5c854e0
# 37  4bf9ddca5efe2d7fa9f76c34
# 40  4a6a3991f964a520e0cc1fe3
# 16  4423cae2f964a52099311fe3
# 45  4c82f8eb309aef3b9d06c681
# 38  4b786cecf964a52052cd2ee3
# 15  44281118f964a520ba311fe3
# 27  4e4e5595bd4101d0d7a7f203

# %% [markdown]
# ### We merge the location and venue data here.

# %%
def rating_count_extractor(venue_id):
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
    result = requests.get(url).json()
    try:
        num_rated = result['response']['venue'] ['ratingSignals']
        rating = result['response']['venue']['rating']
    except:
        num_rated = 0
        rating = None
    try:
        tip_count = result['response']['venue']['tips']['count']
    except:
        tip_count = 0
    data_list = [venue_id, num_rated, rating, tip_count]
    data_columns = ['Venue_ID', 'Number_of_Rated', 'Rating', 'Tip_Count']
    df = pd.DataFrame([data_list], columns=data_columns)
    return df

venue_ids = total_data['id'].tolist()
total_df = []
for venue_id in venue_ids:
    df = rating_count_extractor(str(venue_id))
    total_df.append(df)

total_df = pd.concat(total_df, ignore_index=True)
df_merge = total_data.merge(total_df, left_on ='id', right_on = 'Venue_ID', how='left')
df_merge.dropna(subset = ['Rating'], inplace=True)

# %% [markdown]
# ### As explained in the beginning of this section, we use 75th percentile on The Total Number of People Who Rated, Ratings, and Tip Comment Counts to determine which venue is hit or miss.  The rationale for choosing these three features as indicators of the target variable is that we want to know which venues have been visited by a lot of people and rated well.  If a venue was rated well, people tend to come back.

# %%
clean_list = ['name', 'categories', 'lat', 'lng','Number_of_Rated', 'Rating', 'Tip_Count', 'formattedAddress']
df_merge_clean = df_merge[clean_list]
sfperc_num_rated = np.percentile(df_merge_clean['Number_of_Rated'], 75)
sfperc_rating = np.percentile(df_merge_clean['Rating'], 75)
sfperc_tip_count = np.percentile(df_merge_clean['Tip_Count'], 75)

conditions = [((df_merge_clean['Number_of_Rated'] >= sfperc_num_rated) & (df_merge_clean['Rating'] >= sfperc_rating) & (df_merge_clean['Tip_Count'] >= sfperc_tip_count)),
             ((df_merge_clean['Number_of_Rated'] < sfperc_num_rated) | (df_merge_clean['Rating'] < sfperc_rating))]
values = ['Hit', 'Miss']
df_merge_clean['Potential_Spot_Flag'] = np.select(conditions, values)
df_merge_clean.dropna(inplace=True)
df_merge_final = df_merge_clean[df_merge_clean['Potential_Spot_Flag']=='Hit']
df_merge_final
# Out:
# <ipython-input-32-3442635c4067>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merge_clean['Potential_Spot_Flag'] = np.select(conditions, values)
# <ipython-input-32-3442635c4067>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merge_clean.dropna(inplace=True)
#                               name           categories        lat        lng  \
# 6                 Galli Restaurant   Italian Restaurant  40.721607 -74.001235
# 14         Bo Ky Restaurant 波記潮州小食   Chinese Restaurant  40.715696 -73.998667
# 17      Deluxe Green Bo Restaurant   Chinese Restaurant  40.715545 -73.998137
# 23  Golden Unicorn Restaurant 麒麟金閣   Dim Sum Restaurant  40.713629 -73.997230
# 29             Arturo's Restaurant   Italian Restaurant  40.727407 -74.000378
# 32                Frank Restaurant   Italian Restaurant  40.726939 -73.988899
# 61           Heidelberg Restaurant    German Restaurant  40.777532 -73.951979
# 68    Carmine's Italian Restaurant   Italian Restaurant  40.791096 -73.973991
# 72        Yuka Japanese Restaurant     Sushi Restaurant  40.774581 -73.954206
# 75               Fred's Restaurant  American Restaurant  40.785658 -73.976539
#
#     Number_of_Rated Rating  Tip_Count  \
# 6               716    8.2        141
# 14              229    8.1         74
# 17              326    8.3        135
# 23             1187    8.0        228
# 29              463    8.5        133
# 32              606    8.8        164
# 61              360    8.8        104
# 68              579    8.3        132
# 72              233    8.0         97
# 75              583    8.2        149
#
#                                      formattedAddress Potential_Spot_Flag
# 6   [45 Mercer St (Broome & Grand Streets), New Yo...                 Hit
# 14    [80 Bayard St (at Mott St), New York, NY 10013]                 Hit
# 17  [66 Bayard St (btwn Elizabeth & Mott St), New ...                 Hit
# 23  [18 E Broadway (at Catherine St), New York, NY...                 Hit
# 29  [106 W Houston St (at Thompson St.), New York,...                 Hit
# 32     [88 2nd Ave (at E 5th St), New York, NY 10003]                 Hit
# 61  [1648 2nd Ave (btwn 85th & 86th St.), New York...                 Hit
# 68  [2450 Broadway (btwn W 90th & W 91st), New Yor...                 Hit
# 72  [1557 2nd Ave (btwn E 80th & E 81st St), New Y...                 Hit
# 75  [476 Amsterdam Ave. (at W 83rd St), New York, ...                 Hit

# %%
df_merge_final = df_merge_final.iloc[[0,1,2,3,4,5],:]

# %% [markdown]
# ### We can clearly see there are three potential hit areas in this map.

# %%
venues_map = folium.Map(location=["40.7128", "-74.0060"], zoom_start=11)

# add the BBQ restaurants as blue circle markers
for lat, lng, label in zip(df_merge_final.lat, df_merge_final.lng, df_merge_final.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0471c51000984e2a82de5de0b6cd9ea5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0471c51000984e2a82de5de0b6cd9ea5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0471c51000984e2a82de5de0b6cd9ea5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0471c51000984e2a82de5de0b6cd9ea5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7128%2C%20-74.006%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## *Results*
# #### After running a data visualization, we were able to find three potential hit areas.  Out of these three areas, lower Manhattan seems to be the best opportunity for an area to open a KBBQ restaurant as there is very high population traffic and no KBBQ or any other types of BBQ restaurants are present.  Let us see the map below.

# %%
venues_map = folium.Map(location=["40.7128", "-74.0060"], zoom_start=14)

# add the BBQ restaurants as blue circle markers
for lat, lng, label in zip(df_merge_final.lat, df_merge_final.lng, df_merge_final.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

coordinates = [[lat, lng] for lat, lng in zip(df_merge_final.lat, df_merge_final.lng)]
# folium.PolyLine(coordinates, line_color='#FF0000', line_weight=5).add_to(venues_map)

avg_lat = np.mean(df_merge_final.lat)
std_lat = np.std(df_merge_final.lat)
avg_lng = np.mean(df_merge_final.lng)
std_lng = np.std(df_merge_final.lng)

folium.CircleMarker(
    [avg_lat+0.2*std_lat, avg_lng+0.6*std_lng],
    radius = 120,
    color='green',
    fill=True,
    fill_color='green',
    fill_opacity=0.2
).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_cc389cdf663a426fb1f478bd2b73808d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cc389cdf663a426fb1f478bd2b73808d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_cc389cdf663a426fb1f478bd2b73808d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_cc389cdf663a426fb1f478bd2b73808d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7128%2C%20-74.006%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## *Discussion*
# #### In this project, I refrained from using any of the existing machine learning algorithms for reasons.  The first reason was the shear amount of data for this project.  You can see from the methodology section that we do not have sufficient amount of data to train and test a model.  Second, it was too open to approach with unsupervised way.  I ended up using labels but you can also approach this with an unsupervised method by adding more features and try to group them based on those features.  Normally, unsupervised learning requires a lot more data than supervised learning, so for the sake of this project, I stayed with labels.  Choosing 75th percentile was my pure subjective choice, so this most certainly have introduced bias in my analysis.  However the bias, based on the feature metrics of the surrounding restaurants, the area picked for the KBBQ will be populated by many people and will have a lot of patronage opportunities if the food is served right.

# %% [markdown]
# ## *Conclusion*
# #### We set out to find what seemingly a very broad idea: "KBBQ seems very profitable and can we find the best location for a venue in Manhattan?"  Coupled with location and venue data, this broad idea became a very specific goal.  Even without sufficient amount of data and without using fancy machine learning algorithms, just employing simple data preprocessing, statistical methods, and data visualization, we were able to pinpoint an area where a potential investor in food industry can make profits running a KBBQ restaurant or restaurants.

# %% [markdown]
# ## Thank you for reading!
