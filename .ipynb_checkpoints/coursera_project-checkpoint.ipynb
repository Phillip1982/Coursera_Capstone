# %%
# ! pip uninstall jupyterlab_server --yes
# ! pip uninstall slugify --yes
# ! pip install jupyterlab_server==1.1.5
# ! pip install slugify
# Out:
# Found existing installation: jupyterlab-server 2.3.0
# Uninstalling jupyterlab-server-2.3.0:
#   Successfully uninstalled jupyterlab-server-2.3.0
# Found existing installation: slugify 0.0.1
# Uninstalling slugify-0.0.1:
#   Successfully uninstalled slugify-0.0.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting jupyterlab_server==1.1.5
#   Downloading jupyterlab_server-1.1.5-py3-none-any.whl (29 kB)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyterlab_server==1.1.5) (3.2.0)
# Requirement already satisfied: jinja2>=2.10 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyterlab_server==1.1.5) (2.11.2)
# Requirement already satisfied: notebook>=4.2.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyterlab_server==1.1.5) (6.1.4)
# Requirement already satisfied: json5 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyterlab_server==1.1.5) (0.9.5)
# Requirement already satisfied: requests in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyterlab_server==1.1.5) (2.24.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab_server==1.1.5) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab_server==1.1.5) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab_server==1.1.5) (20.3.0)
# Requirement already satisfied: setuptools in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab_server==1.1.5) (53.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jinja2>=2.10->jupyterlab_server==1.1.5) (1.1.1)
# Requirement already satisfied: tornado>=5.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (6.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (4.6.3)
# Requirement already satisfied: pyzmq>=17 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (19.0.2)
# Requirement already satisfied: traitlets>=4.2.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (5.0.5)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (6.1.7)
# Requirement already satisfied: terminado>=0.8.3 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (0.9.1)
# Requirement already satisfied: prometheus-client in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (0.8.0)
# Requirement already satisfied: ipykernel in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (5.3.4)
# Requirement already satisfied: argon2-cffi in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (20.1.0)
# Requirement already satisfied: nbconvert in /Users/phillipkim/Library/Python/3.8/lib/python/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (5.6.1)
# Requirement already satisfied: ipython-genutils in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (0.2.0)
# Requirement already satisfied: nbformat in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (5.0.8)
# Requirement already satisfied: Send2Trash in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook>=4.2.0->jupyterlab_server==1.1.5) (1.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from requests->jupyterlab_server==1.1.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from requests->jupyterlab_server==1.1.5) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from requests->jupyterlab_server==1.1.5) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from requests->jupyterlab_server==1.1.5) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=4.2.0->jupyterlab_server==1.1.5) (2.8.1)
# Requirement already satisfied: ptyprocess in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from terminado>=0.8.3->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.6.0)
# Requirement already satisfied: ipython>=5.0.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipykernel->notebook>=4.2.0->jupyterlab_server==1.1.5) (7.19.0)
# Requirement already satisfied: appnope; platform_system == "Darwin" in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipykernel->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.2.0->jupyterlab_server==1.1.5) (1.14.3)
# Requirement already satisfied: defusedxml in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.6.0)
# Requirement already satisfied: testpath in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.4.4)
# Requirement already satisfied: pygments in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.2.0->jupyterlab_server==1.1.5) (2.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.2.0->jupyterlab_server==1.1.5) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.3)
# Requirement already satisfied: bleach in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.2.0->jupyterlab_server==1.1.5) (3.2.1)
# Requirement already satisfied: decorator in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.2.0->jupyterlab_server==1.1.5) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.17.2)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.2.0->jupyterlab_server==1.1.5) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.2.0->jupyterlab_server==1.1.5) (3.0.8)
# Requirement already satisfied: pickleshare in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.7.5)
# Requirement already satisfied: backcall in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.2.0)
# Requirement already satisfied: pycparser in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.2.0->jupyterlab_server==1.1.5) (2.20)
# Requirement already satisfied: webencodings in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.5.1)
# Requirement already satisfied: packaging in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.2.0->jupyterlab_server==1.1.5) (20.4)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=4.2.0->jupyterlab_server==1.1.5) (0.2.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.2.0->jupyterlab_server==1.1.5) (2.4.7)
# Installing collected packages: jupyterlab-server
# Successfully installed jupyterlab-server-1.1.5
# Defaulting to user installation because normal site-packages is not writeable
# Processing /Users/phillipkim/Library/Caches/pip/wheels/a2/49/ff/b5d3130b393f908f0faebf7b4069b259e97d23821826553a76/slugify-0.0.1-py3-none-any.whl
# Installing collected packages: slugify
# Successfully installed slugify-0.0.1

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update


# Create a dash application
app = JupyterDash(__name__)
JupyterDash.infer_jupyter_proxy_config()

# REVIEW1: Clear the layout and do not display exception till callback gets executed
app.config.suppress_callback_exceptions = True

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})


# List of years 
year_list = [i for i in range(2005, 2021, 1)]

"""Compute graph data for creating yearly airline performance report 

Function that takes airline data as input and create 5 dataframes based on the grouping condition to be used for plottling charts and grphs.

Argument:
     
    df: Filtered dataframe
    
Returns:
   Dataframes to create graph. 
"""
def compute_data_choice_1(df):
    # Cancellation Category Count
    bar_data = df.groupby(['Month','CancellationCode'])['Flights'].sum().reset_index()
    # Average flight time by reporting airline
    line_data = df.groupby(['Month','Reporting_Airline'])['AirTime'].mean().reset_index()
    # Diverted Airport Landings
    div_data = df[df['DivAirportLandings'] != 0.0]
    # Source state count
    map_data = df.groupby(['OriginState'])['Flights'].sum().reset_index()
    # Destination state count
    tree_data = df.groupby(['DestState', 'Reporting_Airline'])['Flights'].sum().reset_index()
    return bar_data, line_data, div_data, map_data, tree_data


"""Compute graph data for creating yearly airline delay report

This function takes in airline data and selected year as an input and performs computation for creating charts and plots.

Arguments:
    df: Input airline data.
    
Returns:
    Computed average dataframes for carrier delay, weather delay, NAS delay, security delay, and late aircraft delay.
"""
def compute_data_choice_2(df):
    # Compute delay averages
    avg_car = df.groupby(['Month','Reporting_Airline'])['CarrierDelay'].mean().reset_index()
    avg_weather = df.groupby(['Month','Reporting_Airline'])['WeatherDelay'].mean().reset_index()
    avg_NAS = df.groupby(['Month','Reporting_Airline'])['NASDelay'].mean().reset_index()
    avg_sec = df.groupby(['Month','Reporting_Airline'])['SecurityDelay'].mean().reset_index()
    avg_late = df.groupby(['Month','Reporting_Airline'])['LateAircraftDelay'].mean().reset_index()
    return avg_car, avg_weather, avg_NAS, avg_sec, avg_late


# Application layout
app.layout = html.Div(children=[html.H1('US Domestic Airline Flights Performance', 
                                         style={'textAlign': 'center',
                                                'color': '#503D36',
                                                 'font-size': 24}),
                                # REVIEW2: Dropdown creation
                                # Create an outer division 
                                html.Div([
                                    # Add an division
                                    html.Div([
                                        # Create an division for adding dropdown helper text for report type
                                        html.Div(
                                            [
                                            html.H2('Report Type:', style={'margin-right': '2em'}),
                                            ]
                                        ),
                                        # TODO2: Add a dropdown
                                        
                                    # Place them next to each other using the division style
                                    ], style={'display':'flex'}),
                                    
                                   # Add next division 
                                   html.Div([
                                       # Create an division for adding dropdown helper text for choosing year
                                        html.Div(
                                            [
                                            html.H2('Choose Year:', style={'margin-right': '2em'})
                                            ]
                                        ),
                                        dcc.Dropdown(id='input-year', 
                                                     # Update dropdown values using list comphrehension
                                                     options=[{'label': i, 'value': i} for i in year_list],
                                                     placeholder="Select a year",
                                                     style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'}),
                                            # Place them next to each other using the division style
                                            ], style={'display': 'flex'}),  
                                          ]),
                                
                                # Add Computed graphs
                                # REVIEW3: Observe how we add an empty division and providing an id that will be updated during callback
                                html.Div([ ], id='plot1'),
    
                                html.Div([
                                        html.Div([ ], id='plot2'),
                                        html.Div([ ], id='plot3')
                                ], style={'display': 'flex'}),
                                
                                # TODO3: Add a division with two empty divisions inside. See above disvision for example.
                               
                                ])

# Callback function definition
# TODO4: Add 5 ouput components
@app.callback( [....],
               [Input(component_id='input-type', component_property='value'),
                Input(component_id='input-year', component_property='value')],
               # REVIEW4: Holding output state till user enters all the form information. In this case, it will be chart type and year
               [State("plot1", 'children'), State("plot2", "children"),
                State("plot3", "children"), State("plot4", "children"),
                State("plot5", "children")
               ])
# Add computation to callback function and return graph
def get_graph(chart, year, children1, children2, c3, c4, c5):
      
        # Select data
        df =  airline_data[airline_data['Year']==int(year)]
       
        if chart == 'OPT1':
            # Compute required information for creating graph from the data
            bar_data, line_data, div_data, map_data, tree_data = compute_data_choice_1(df)
            
            # Number of flights under different cancellation categories
            bar_fig = px.bar(bar_data, x='Month', y='Flights', color='CancellationCode', title='Monthly Flight Cancellation')
            
            # TODO5: Average flight time by reporting airline
            
            
            # Percentage of diverted airport landings per reporting airline
            pie_fig = px.pie(div_data, values='Flights', names='Reporting_Airline', title='% of flights by reporting airline')
            
            # REVIEW5: Number of flights flying from each state using choropleth
            map_fig = px.choropleth(map_data,  # Input data
                    locations='OriginState', 
                    color='Flights',  
                    hover_data=['OriginState', 'Flights'], 
                    locationmode = 'USA-states', # Set to plot as US States
                    color_continuous_scale='GnBu',
                    range_color=[0, map_data['Flights'].max()]) 
            map_fig.update_layout(
                    title_text = 'Number of flights from origin state', 
                    geo_scope='usa') # Plot only the USA instead of globe
            
            # TODO6: Number of flights flying to each state from each reporting airline
            
            
            
            # REVIEW6: Return dcc.Graph component to the empty division
            return [dcc.Graph(figure=tree_fig), 
                    dcc.Graph(figure=pie_fig),
                    dcc.Graph(figure=map_fig),
                    dcc.Graph(figure=bar_fig),
                    dcc.Graph(figure=line_fig)
                   ]
        else:
            # REVIEW7: This covers chart type 2 and we have completed this exercise under Flight Delay Time Statistics Dashboard section
            # Compute required information for creating graph from the data
            avg_car, avg_weather, avg_NAS, avg_sec, avg_late = compute_data_choice_2(df)
            
            # Create graph
            carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')
            weather_fig = px.line(avg_weather, x='Month', y='WeatherDelay', color='Reporting_Airline', title='Average weather delay time (minutes) by airline')
            nas_fig = px.line(avg_NAS, x='Month', y='NASDelay', color='Reporting_Airline', title='Average NAS delay time (minutes) by airline')
            sec_fig = px.line(avg_sec, x='Month', y='SecurityDelay', color='Reporting_Airline', title='Average security delay time (minutes) by airline')
            late_fig = px.line(avg_late, x='Month', y='LateAircraftDelay', color='Reporting_Airline', title='Average late aircraft delay time (minutes) by airline')
            
            return[dcc.Graph(figure=carrier_fig), 
                   dcc.Graph(figure=weather_fig), 
                   dcc.Graph(figure=nas_fig), 
                   dcc.Graph(figure=sec_fig), 
                   dcc.Graph(figure=late_fig)]


# Run the app
if __name__ == '__main__':
    # REVIEW8: Adding dev_tools_ui=False, dev_tools_props_check=False can prevent error appearing before calling callback function
    app.run_server(mode="inline", host="localhost", debug=False, dev_tools_ui=False, dev_tools_props_check=False)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://localhost:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
