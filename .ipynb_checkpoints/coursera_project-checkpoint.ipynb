# %%
# ! pip uninstall jupyterlab_server --yes
# ! pip uninstall slugify --yes
# ! pip install jupyterlab_server==1.1.5
# ! pip install slugify
# ! pip install "jupyterlab>=1.0" jupyterlab-dash==0.1.0a3
# pd.set_option("display.max_columns", 110)
# airline_data.head()
# ! pip install jupyter-plotly-dash
# Out:
# Requirement already satisfied: jupyter-plotly-dash in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (0.4.3)
# Requirement already satisfied: jupyter in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter-plotly-dash) (1.0.0)
# Requirement already satisfied: nbserverproxy in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter-plotly-dash) (0.8.8)
# Requirement already satisfied: django-plotly-dash in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter-plotly-dash) (1.6.3)
# Requirement already satisfied: dpd-static-support in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter-plotly-dash) (0.0.5)
# Requirement already satisfied: django-bootstrap4 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter-plotly-dash) (2.3.1)
# Requirement already satisfied: dpd-components in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter-plotly-dash) (0.1.0)
# Requirement already satisfied: aiohttp in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter-plotly-dash) (3.7.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (20.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (5.1.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (3.0.1)
# Requirement already satisfied: chardet<4.0,>=2.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (3.7.4.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (1.6.3)
# Requirement already satisfied: idna>=2.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp->jupyter-plotly-dash) (2.10)
# Requirement already satisfied: django<4.0,>=2.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django-bootstrap4->jupyter-plotly-dash) (3.1.7)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.8.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django-bootstrap4->jupyter-plotly-dash) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from beautifulsoup4<5.0.0,>=4.8.0->django-bootstrap4->jupyter-plotly-dash) (2.2.1)
# Requirement already satisfied: asgiref<4,>=3.2.10 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django<4.0,>=2.2->django-bootstrap4->jupyter-plotly-dash) (3.3.1)
# Requirement already satisfied: pytz in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django<4.0,>=2.2->django-bootstrap4->jupyter-plotly-dash) (2021.1)
# Requirement already satisfied: sqlparse>=0.2.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django<4.0,>=2.2->django-bootstrap4->jupyter-plotly-dash) (0.4.1)
# Requirement already satisfied: dash-core-components in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (1.15.0)
# Requirement already satisfied: dash-renderer in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (1.9.0)
# Requirement already satisfied: plotly in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (4.14.3)
# Requirement already satisfied: Flask>=1.0.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (1.1.2)
# Requirement already satisfied: dash-html-components in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (1.1.2)
# Requirement already satisfied: dash>=1.11 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (1.19.0)
# Requirement already satisfied: future in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from dash>=1.11->django-plotly-dash->jupyter-plotly-dash) (0.18.2)
# Requirement already satisfied: dash-table==4.11.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from dash>=1.11->django-plotly-dash->jupyter-plotly-dash) (4.11.2)
# Requirement already satisfied: flask-compress in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from dash>=1.11->django-plotly-dash->jupyter-plotly-dash) (1.9.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter-plotly-dash) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter-plotly-dash) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter-plotly-dash) (1.0.1)
# Requirement already satisfied: click>=5.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter-plotly-dash) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->django-plotly-dash->jupyter-plotly-dash) (1.1.1)
# Requirement already satisfied: brotli in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from flask-compress->dash>=1.11->django-plotly-dash->jupyter-plotly-dash) (1.0.9)
# Requirement already satisfied: ipykernel in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (5.3.4)
# Requirement already satisfied: qtconsole in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (5.0.3)
# Requirement already satisfied: nbconvert in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (6.0.7)
# Requirement already satisfied: jupyter-console in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (6.4.0)
# Requirement already satisfied: notebook in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (6.3.0)
# Requirement already satisfied: ipywidgets in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (7.6.3)
# Requirement already satisfied: jupyter-client in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (6.1.12)
# Requirement already satisfied: appnope in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (0.1.2)
# Requirement already satisfied: traitlets>=4.1.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (5.0.5)
# Requirement already satisfied: tornado>=4.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (6.1)
# Requirement already satisfied: ipython>=5.0.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (7.21.0)
# Requirement already satisfied: pygments in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (2.8.1)
# Requirement already satisfied: decorator in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (4.4.2)
# Requirement already satisfied: pexpect>4.3 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (3.0.17)
# Requirement already satisfied: setuptools>=18.5 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (53.0.0)
# Requirement already satisfied: backcall in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->jupyter->jupyter-plotly-dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from traitlets>=4.1.0->ipykernel->jupyter->jupyter-plotly-dash) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipywidgets->jupyter->jupyter-plotly-dash) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipywidgets->jupyter->jupyter-plotly-dash) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from ipywidgets->jupyter->jupyter-plotly-dash) (5.1.2)
# Requirement already satisfied: jupyter-core in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->jupyter-plotly-dash) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->jupyter-plotly-dash) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->jupyter-plotly-dash) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->jupyter-plotly-dash) (1.15.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->jupyter-plotly-dash) (0.9.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->jupyter-plotly-dash) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->jupyter-plotly-dash) (20.0.0)
# Requirement already satisfied: argon2-cffi in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->jupyter-plotly-dash) (20.1.0)
# Requirement already satisfied: prometheus-client in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->jupyter-plotly-dash) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel->jupyter->jupyter-plotly-dash) (2.8.1)
# Requirement already satisfied: cffi>=1.0.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter->jupyter-plotly-dash) (1.14.5)
# Requirement already satisfied: pycparser in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->jupyter-plotly-dash) (2.20)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.8.4)
# Requirement already satisfied: bleach in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (3.3.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.1.2)
# Requirement already satisfied: testpath in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (1.4.3)
# Requirement already satisfied: defusedxml in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.7.1)
# Requirement already satisfied: async-generator in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->jupyter-plotly-dash) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->jupyter-plotly-dash) (1.5.1)
# Requirement already satisfied: packaging in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->jupyter-plotly-dash) (20.9)
# Requirement already satisfied: webencodings in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->jupyter-plotly-dash) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert->jupyter->jupyter-plotly-dash) (2.4.7)
# Requirement already satisfied: retrying>=1.3.3 in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from plotly->django-plotly-dash->jupyter-plotly-dash) (1.3.3)
# Requirement already satisfied: qtpy in /Users/phillipkim/anaconda3/lib/python3.8/site-packages (from qtconsole->jupyter->jupyter-plotly-dash) (1.9.0)

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update

# Create a dash application
app = JupyterDash(__name__)
JupyterDash.infer_jupyter_proxy_config()

# REVIEW1: Clear the layout and do not display exception till callback gets executed
app.config.suppress_callback_exceptions = True

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})


# List of years 
year_list = [i for i in range(2005, 2021, 1)]

"""Compute graph data for creating yearly airline performance report 

Function that takes airline data as input and create 5 dataframes based on the grouping condition to be used for plottling charts and grphs.

Argument:
     
    df: Filtered dataframe
    
Returns:
   Dataframes to create graph. 
"""
def compute_data_choice_1(df):
    # Cancellation Category Count
    bar_data = df.groupby(['Month','CancellationCode'])['Flights'].sum().reset_index()
    # Average flight time by reporting airline
    line_data = df.groupby(['Month','Reporting_Airline'])['AirTime'].mean().reset_index()
    # Diverted Airport Landings
    div_data = df[df['DivAirportLandings'] != 0.0]
    # Source state count
    map_data = df.groupby(['OriginState'])['Flights'].sum().reset_index()
    # Destination state count
    tree_data = df.groupby(['DestState', 'Reporting_Airline'])['Flights'].sum().reset_index()
    return bar_data, line_data, div_data, map_data, tree_data


"""Compute graph data for creating yearly airline delay report

This function takes in airline data and selected year as an input and performs computation for creating charts and plots.

Arguments:
    df: Input airline data.
    
Returns:
    Computed average dataframes for carrier delay, weather delay, NAS delay, security delay, and late aircraft delay.
"""
def compute_data_choice_2(df):
    # Compute delay averages
    avg_car = df.groupby(['Month','Reporting_Airline'])['CarrierDelay'].mean().reset_index()
    avg_weather = df.groupby(['Month','Reporting_Airline'])['WeatherDelay'].mean().reset_index()
    avg_NAS = df.groupby(['Month','Reporting_Airline'])['NASDelay'].mean().reset_index()
    avg_sec = df.groupby(['Month','Reporting_Airline'])['SecurityDelay'].mean().reset_index()
    avg_late = df.groupby(['Month','Reporting_Airline'])['LateAircraftDelay'].mean().reset_index()
    return avg_car, avg_weather, avg_NAS, avg_sec, avg_late


# Application layout
app.layout = html.Div(children=[html.H1('US Domestic Airline Flights Performance', 
                                         style={'textAlign': 'center',
                                                'color': '#503D36',
                                                 'font-size': 24}),
                                # REVIEW2: Dropdown creation
                                # Create an outer division 
                                html.Div([
                                    # Add an division
                                    html.Div([
                                        # Create an division for adding dropdown helper text for report type
                                        html.Div(
                                            [
                                            html.H2('Report Type:', style={'margin-right': '2em'}),
                                            ]
                                        ),
                                        # TODO2: Add a dropdown
                                        dcc.Dropdown(id='input-type', 
                                                     # Update dropdown values using list comphrehension
                                                     options=[{'label': 'Yearly airline performance report', 'value':'OPT1'},
                                                             {'label': 'Yearly average flight delay statistics', 'value':'OPT2'}],
                                                     value = 'Yearly airline performance report',
                                                     placeholder="Select a report type",
                                                     style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'})
                                            # Place them next to each other using the division style
                                            ], style={'display': 'flex'}), 
                                    
                                   # Add next division 
                                   html.Div([
                                       # Create an division for adding dropdown helper text for choosing year
                                        html.Div(
                                            [
                                            html.H2('Choose Year:', style={'margin-right': '2em'})
                                            ]
                                        ),
                                        dcc.Dropdown(id='input-year', 
                                                     # Update dropdown values using list comphrehension
                                                     options=[{'label': i, 'value': i} for i in year_list],
                                                     value='2005',
                                                     placeholder="Select a year",
                                                     style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'}), 
                                            # Place them next to each other using the division style
                                            ], style={'display': 'flex'}),  
                                          ]),
                                
                                # Add Computed graphs
                                # REVIEW3: Observe how we add an empty division and providing an id that will be updated during callback
                                html.Div([ ], id='plot1'),
    
                                html.Div([
                                        html.Div([ ], id='plot2'),
                                        html.Div([ ], id='plot3')
                                ], style={'display': 'flex'}),
                                
                                # TODO3: Add a division with two empty divisions inside. See above disvision for example.
                                html.Div([
                                        html.Div([ ], id='plot4'),
                                        html.Div([ ], id='plot5')
                                ], style={'display': 'flex'}),                               
                                ])

# Callback function definition
# TODO4: Add 5 ouput components
@app.callback( [Output(component_id='plot1', component_property='children'),
               Output(component_id='plot2', component_property='children'),
               Output(component_id='plot3', component_property='children'),
               Output(component_id='plot4', component_property='children'),
               Output(component_id='plot5', component_property='children')],
               [Input(component_id='input-type', component_property='value'),
                Input(component_id='input-year', component_property='value')],
               # REVIEW4: Holding output state till user enters all the form information. In this case, it will be chart type and year
               [State("plot1", 'children'), State("plot2", "children"),
                State("plot3", "children"), State("plot4", "children"),
                State("plot5", "children")
               ])
# Add computation to callback function and return graph
def get_graph(chart, year, children1, children2, c3, c4, c5):
    # Select data
    df =  airline_data[airline_data['Year']==int(year)]

    if chart == 'OPT1':
        # Compute required information for creating graph from the data
        bar_data, line_data, div_data, map_data, tree_data = compute_data_choice_1(df)

        # Number of flights under different cancellation categories
        bar_fig = px.bar(bar_data, x='Month', y='Flights', color='CancellationCode', title='Monthly Flight Cancellation')

        # TODO5: Average flight time by reporting airline
        line_fig = px.line(line_data, x='Month', y='AirTime', color='Reporting_Airline', title='Average monthly flight time (minutes) by airline')

        # Percentage of diverted airport landings per reporting airline
        pie_fig = px.pie(div_data, values='Flights', names='Reporting_Airline', title='% of flights by reporting airline')

        # REVIEW5: Number of flights flying from each state using choropleth
        map_fig = px.choropleth(map_data,  # Input data
                locations='OriginState', 
                color='Flights',  
                hover_data=['OriginState', 'Flights'], 
                locationmode = 'USA-states', # Set to plot as US States
                color_continuous_scale='GnBu',
                range_color=[0, map_data['Flights'].max()]) 
        map_fig.update_layout(
                title_text = 'Number of flights from origin state', 
                geo_scope='usa') # Plot only the USA instead of globe

        # TODO6: Number of flights flying to each state from each reporting airline
        tree_fig = px.treemap(tree_data, path=['DestState', 'Reporting_Airline'], 
                              values='Flights',
                              color='Flights',
                              color_continuous_scale='RdBu',
                              title='Flight count by airline to destination state')
        # REVIEW6: Return dcc.Graph component to the empty division
        return [dcc.Graph(figure=tree_fig), 
                dcc.Graph(figure=pie_fig),
                dcc.Graph(figure=map_fig),
                dcc.Graph(figure=bar_fig),
                dcc.Graph(figure=line_fig)
               ]
    else:
        # REVIEW7: This covers chart type 2 and we have completed this exercise under Flight Delay Time Statistics Dashboard section
        # Compute required information for creating graph from the data
        avg_car, avg_weather, avg_NAS, avg_sec, avg_late = compute_data_choice_2(df)

        # Create graph
        carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')
        weather_fig = px.line(avg_weather, x='Month', y='WeatherDelay', color='Reporting_Airline', title='Average weather delay time (minutes) by airline')
        nas_fig = px.line(avg_NAS, x='Month', y='NASDelay', color='Reporting_Airline', title='Average NAS delay time (minutes) by airline')
        sec_fig = px.line(avg_sec, x='Month', y='SecurityDelay', color='Reporting_Airline', title='Average security delay time (minutes) by airline')
        late_fig = px.line(avg_late, x='Month', y='LateAircraftDelay', color='Reporting_Airline', title='Average late aircraft delay time (minutes) by airline')

        return[dcc.Graph(figure=carrier_fig), 
               dcc.Graph(figure=weather_fig), 
               dcc.Graph(figure=nas_fig), 
               dcc.Graph(figure=sec_fig), 
               dcc.Graph(figure=late_fig)]

# Run the app
if __name__ == '__main__':
    # REVIEW8: Adding dev_tools_ui=False, dev_tools_props_check=False can prevent error appearing before calling callback function
    app.run_server(mode="inline", host="localhost", debug=False, dev_tools_ui=False, dev_tools_props_check=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-0c3859fec9bf> in <module>
#      12 # Create a dash application
#      13 app = JupyterDash(__name__)
# ---> 14 JupyterDash.infer_jupyter_proxy_config()
#      15
#      16 # REVIEW1: Clear the layout and do not display exception till callback gets executed
#
# ~/anaconda3/lib/python3.8/site-packages/jupyter_dash/jupyter_app.py in infer_jupyter_proxy_config(cls)
#      71         else:
#      72             # Assume classic notebook or JupyterLab
# ---> 73             _request_jupyter_config()
#      74
#      75     def __init__(self, name=None, server_url=None, **kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/jupyter_dash/comms.py in _request_jupyter_config(timeout)
#      60         if (time.time() - t0) > timeout:
#      61             # give up
# ---> 62             raise EnvironmentError(
#      63                 "Unable to communicate with the jupyter_dash notebook or JupyterLab \n"
#      64                 "extension required to infer Jupyter configuration."
#
# OSError: Unable to communicate with the jupyter_dash notebook or JupyterLab
# extension required to infer Jupyter configuration.
